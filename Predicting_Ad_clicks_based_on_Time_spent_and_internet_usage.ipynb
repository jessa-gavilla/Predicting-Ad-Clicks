# %%
# IMPORT GENERIC PACKAGES
import numpy as np # numerical calc package
import pandas as pd # holds data
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # pretty plotting

sns.set(rc={'figure.figsize':(20,10)})

from sklearn.model_selection import train_test_split # split dataset

from sklearn.linear_model import LogisticRegression # linear model for classification

from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('advertising_classification.csv')

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %%
# write list of features we want to use
features = ["Daily Time Spent on Site", "Age"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
# Statistical Summary
X_train.describe()
# Out:
#        Daily Time Spent on Site         Age
# count                600.000000  600.000000
# mean                  65.379200   35.986667
# std                   15.836272    8.871546
# min                   32.840000   19.000000
# 25%                   51.632500   29.000000
# 50%                   68.700000   35.000000
# 75%                   78.710000   42.000000
# max                   91.430000   61.000000

# %%
# distributions
sns.pairplot(X_train)

# %%
# correlations
X_train.corr()
# Out:
#                           Daily Time Spent on Site       Age
# Daily Time Spent on Site                  1.000000 -0.288115
# Age                                      -0.288115  1.000000

# %%
# heatmap of correlations
sns.heatmap(X_train.corr(), annot = True)

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.8883333333333333

# %%
# write list of features we want to use
features = ["Daily Time Spent on Site", "Age", "Area Income", "Daily Internet Usage"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
# distributions
sns.pairplot(X_train)

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.8933333333333333

# %%
# write list of features we want to use
features = ["Daily Time Spent on Site", "Daily Internet Usage"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.8933333333333333

# %%
# confusion matrix
cf = confusion_matrix(y_test, y_pred)
cf
# Out:
# array([[183,   8],
#        [ 33, 176]])

# %%
# heatmap of confusion matrix 
sns.heatmap(cf, annot = True)

# %%
# write list of features we want to use
features = ["Daily Time Spent on Site","Daily Internet Usage", "Age"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.8933333333333333

# %%
# write list of features we want to use
features = ["Age", "Daily Internet Usage"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.9066666666666666

# %%
# confusion matrix
cf = confusion_matrix(y_test, y_pred)
cf
# Out:
# array([[176,  15],
#        [ 28, 181]])

# %%
# heatmap of confusion matrix 
sns.heatmap(cf, annot = True)

# %%
# write list of features we want to use
features = ["Daily Time Spent on Site", "Daily Internet Usage"]

# Set X
X = data[features]

# Set y
y = data["Clicked on Ad"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 42)

# %%
# initialize model
log_reg = LogisticRegression()

# fit model
log_reg.fit(X_train, y_train)

# metrics (accuracy)
acc = log_reg.score(X_train, y_train)


# predictions
y_pred = log_reg.predict(X_test)

# %%
# accuracy
acc
# Out:
# 0.9533333333333334

# %%
# confusion matrix
cf = confusion_matrix(y_test, y_pred)
cf
# Out:
# array([[186,   5],
#        [ 18, 191]])

# %%
# heatmap of confusion matrix 
sns.heatmap(cf, annot = True)
